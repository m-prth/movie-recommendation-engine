# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import pickle

# %%
data = pd.read_excel('movie data_new.xlsx')
data.rename(columns={'Unnamed: 0': 'movie_id'}, inplace=True)
columns = ['Cast','Director','Genre','Title','Description']

# %%
def get_important_features(data):
    imp_features = []
    for i in range(0,data.shape[0]):
        imp_features.append(data['Title'][i]+' '+data['Director'][i]+' '+data['Genre'][i]+' '+data['Description'][i])
    return imp_features

# %%
data['imp_features'] = get_important_features(data)

# %%
data
# Out:
#      movie_id                                       Title Year of Release  \
# 0           0                                    Free Guy            2021
# 1           1                           The Suicide Squad            2021
# 2           2                                Reminiscence            2021
# 3           3                                     Beckett            2021
# 4           4                                    Eternals            2021
# ..        ...                                         ...             ...
# 995       995                           The Good Shepherd            2006
# 996       996                                     Falling          I 2020
# 997       997                                        2012          I 2009
# 998       998  Star Wars: Episode VI - Return of the Jedi            1983
# 999       999                                    Oblivion          I 2013
#
#     Watch Time                                     Genre  Movie Rating  \
# 0      115 min      \nAction, Comedy, Sci-Fi                       7.6
# 1      132 min   \nAction, Adventure, Comedy                       7.4
# 2      116 min    \nMystery, Romance, Sci-Fi                       5.9
# 3      110 min        \nAction, Crime, Drama                       5.6
# 4          NaN    \nAction, Adventure, Drama                       NaN
# ..         ...                                       ...           ...
# 995    167 min    \nDrama, History, Thriller                       6.7
# 996    112 min                       \nDrama                       6.4
# 997    158 min   \nAction, Adventure, Sci-Fi                       5.8
# 998    131 min  \nAction, Adventure, Fantasy                       8.3
# 999    124 min   \nAction, Adventure, Sci-Fi                       7.0
#
#      Metascore of movie                    Director  \
# 0                  62.0                  Shawn Levy
# 1                  72.0                  James Gunn
# 2                  46.0                    Lisa Joy
# 3                  52.0  Ferdinando Cito Filomarino
# 4                   NaN                  Chloé Zhao
# ..                  ...                         ...
# 995                61.0              Robert De Niro
# 996                63.0             Viggo Mortensen
# 997                49.0             Roland Emmerich
# 998                58.0            Richard Marquand
# 999                54.0             Joseph Kosinski
#
#                                                  Cast    Votes  \
# 0             Ryan Reynolds,Jodie Comer,Taika Waititi   29,441
# 1                  Margot Robbie,Idris Elba,John Cena  156,225
# 2       Hugh Jackman,Rebecca Ferguson,Thandiwe Newton   11,879
# 3    John David Washington,Boyd Holbrook,Vicky Krieps   14,267
# 4           Richard Madden,Salma Hayek,Angelina Jolie      NaN
# ..                                                ...      ...
# 995          Matt Damon,Angelina Jolie,Robert De Niro  100,403
# 996        Viggo Mortensen,Lance Henriksen,Terry Chen    3,975
# 997      John Cusack,Thandiwe Newton,Chiwetel Ejiofor  362,537
# 998           Mark Hamill,Harrison Ford,Carrie Fisher  982,354
# 999      Tom Cruise,Morgan Freeman,Andrea Riseborough  498,587
#
#                                            Description  \
# 0    A bank teller discovers that he's actually an ...
# 1    Supervillains Harley Quinn, Bloodsport, Peacem...
# 2    Nick Bannister, a private investigator of the ...
# 3    Following a tragic car accident in Greece, Bec...
# 4    The saga of the Eternals, a race of immortal b...
# ..                                                 ...
# 995  The tumultuous early history of the Central In...
# 996  John Peterson lives with his partner Eric and ...
# 997  A frustrated writer struggles to keep his fami...
# 998  After a daring mission to rescue Han Solo from...
# 999  A veteran assigned to extract Earth's remainin...
#
#                                           imp_features
# 0    Free Guy Shawn Levy \nAction, Comedy, Sci-Fi  ...
# 1    The Suicide Squad James Gunn \nAction, Adventu...
# 2    Reminiscence Lisa Joy \nMystery, Romance, Sci-...
# 3    Beckett Ferdinando Cito Filomarino \nAction, C...
# 4    Eternals Chloé Zhao \nAction, Adventure, Drama...
# ..                                                 ...
# 995  The Good Shepherd Robert De Niro \nDrama, Hist...
# 996  Falling Viggo Mortensen \nDrama             Jo...
# 997  2012 Roland Emmerich \nAction, Adventure, Sci-...
# 998  Star Wars: Episode VI - Return of the Jedi Ric...
# 999  Oblivion Joseph Kosinski \nAction, Adventure, ...
#
# [1000 rows x 12 columns]

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(data['imp_features'])
print(tfidf_matrix.shape)

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
print(cosine_sim)
# Out:
# (1000, 6723)
# [[1.         0.01105003 0.0404663  ... 0.03987949 0.00487497 0.03970308]
#  [0.01105003 1.         0.         ... 0.01049528 0.00704997 0.01044886]
#  [0.0404663  0.         1.         ... 0.02498083 0.         0.02487033]
#  ...
#  [0.03987949 0.01049528 0.02498083 ... 1.         0.04720481 0.04932075]
#  [0.00487497 0.00704997 0.         ... 0.04720481 1.         0.03968582]
#  [0.03970308 0.01044886 0.02487033 ... 0.04932075 0.03968582 1.        ]]

# %%
indices = pd.Series(data.index,index=data['Title']).drop_duplicates()
def get_recommendations(title,cosine_sim=cosine_sim):
    idx=indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores,key=lambda x:x[1], reverse=True)
    sim_scores = sim_scores[1:6]
    movie_indices = [i[0] for i in sim_scores]
    movies = data['Title'].iloc[movie_indices]
    id = data['movie_id'].iloc[movie_indices]
    dict = {"Movies":movies,"id":id}
    final_df = pd.DataFrame(dict)
    final_df.reset_index(drop=True,inplace=True)
    return final_df

# %%
get_recommendations('The Wolf of Wall Street')
# Out:
#          Movies   id
# 0  The Irishman  277
# 1    Goodfellas  128
# 2  The Departed  121
# 3    Inside Man  674
# 4        Casino  665

# %%
data.info()
new = data.drop(columns=['Year of Release','Watch Time','Genre','Movie Rating','Metascore of movie','Director','Cast','Votes','Description'])

pickle.dump(new,open('movie_list.pkl','wb'))
pickle.dump(cosine_sim,open('similarity.pkl','wb'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   movie_id            1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Year of Release     1000 non-null   object
#  3   Watch Time          957 non-null    object
#  4   Genre               1000 non-null   object
#  5   Movie Rating        939 non-null    float64
#  6   Metascore of movie  905 non-null    float64
#  7   Director            1000 non-null   object
#  8   Cast                1000 non-null   object
#  9   Votes               939 non-null    object
#  10  Description         1000 non-null   object
#  11  imp_features        1000 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB
